# %%
# Look for ones in the network that we're missing from our classification.
import os
import json

senders = {}
recipients = {}
inputdir = "./final/"
for subdir, dirs, files in os.walk(inputdir):
    for file in files:
        if file[-2:] != "js":
            continue
        json_file = open(subdir + os.sep + file)
        data = json.load(json_file)
        
        for k in ["transactions", "words"]:
            for x in data[k]:
                if "description" not in x:
                    continue
                if x["description"] == "sender":
                   senders[x["transactionID"]] = x["transliteratedWord"] 
                if x["description"] == "recipient":
                   recipients[x["transactionID"]] = x["transliteratedWord"] 
                

print(len(senders), len(recipients))
print(sorted([k for k in senders if k not in recipients]))
print(sorted([k for k in recipients if k not in senders]))
# Out:
# 595 567
# ['ARKH3a-3', 'HT100-0', 'HT100-1', 'HT116a-1', 'HT117a-4', 'HT122b-1', 'HT125a-0', 'HT125b-0', 'HT131a-0', 'HT131b-0', 'HT23a-2', 'HT23a-3', 'HT23a-4', 'HT28a-1', 'HT28a-4', 'HT30-0', 'HT30-2', 'HT32-0', 'HT32-3', 'HT32-4', 'HT58-2', 'HT7a-1', 'HT88-4', 'HT94b-1', 'HT94b-7', 'HT95a-1', 'KH9-3', 'PE1-1']
# []

# %%
""" Get the top connected edges and display them in a table """

# Create a list of all edges
edges = [(senders[k], recipients[k]) for k in recipients]
edges += [(recipients[k], senders[k]) for k in recipients]
edges = sorted(set(edges))

# Create a table with the most connected nodes at the top.
from collections import defaultdict
node_count = defaultdict(int)
for f,t in edges:
    node_count[f] += 1
sorted_node_count = dict(sorted(node_count.items(), key=lambda x:x[1], reverse=True))

import pandas as pd
pd.set_option('display.max_rows', None)
styles = [dict(selector="caption", 
    props=[("text-align", "center"),
    ("font-size", "120%"),
    ("color", 'black')])]

df = pd.DataFrame.from_dict(sorted_node_count, orient='index', columns=['Count'])
df.style.set_caption("Most connected Nodes").set_table_styles(styles)
# Out:
# <style  type="text/css" >
#     #T_c890d_ caption {
#           text-align: center;
#           font-size: 120%;
#           color: black;
#     }</style><table id="T_c890d_" ><caption>Most connected Nodes</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Count</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c890d_level0_row0" class="row_heading level0 row0" >Haghia Triada Magazine</th>
#                         <td id="T_c890d_row0_col0" class="data row0 col0" >126</td>
#             </tr>
#             <tr>
#                         <th id="T_c890d_level0_row1" class="row_heading level0 row1" >Zakros Magazine</th>
#                         <td id="T_c890d_row1_col0" class="data row1 col0" >64</td>
#             </tr>
#             <tr>
#                         <th id="T_c890d_level0_row2" class="row_heading level0 row2" >KA-PA</th>
#                         <td id="T_c890d_row2_col0" class="data row2 col0" >22</td>
#             </tr>
#             <tr>
#                         <th id="T_c890d_level0_row3" class="row_heading level0 row3" >KI-RO</th>
#                         <td id="T_c890d_row3_col0" class="data row3 col0" >18</td>
#             </tr>
#             <tr>
#                         <th id="T_c890d_level0_row4" class="row_heading level0 row4" >A-DU</th>
#                         <td id="T_c890d_row4_col0" class="data row4 col0" >17</td>
#             </tr>
#             <tr>
#                         <th id="T_c890d_level0_row5" class="row_heading level0 row5" >PA</th>
#                         <td id="T_c890d_row5_col0" class="data row5 col0" >15</td>
#             </tr>
#             <tr>
#                         <th id="T_c890d_level0_row6" class="row_heading level0 row6" >]-RA-RI</th>
#                         <td id="T_c890d_row6_col0" class="data row6 col0" >15</td>
#             </tr>
#             <tr>
#                         <th id="T_c890d_level0_row7" class="row_heading level0 row7" >KI-KI-RA-JA</th>
#                         <td id="T_c890d_row7_col0" class="data row7 col0" >11</td>
#             </tr>
#             <tr>
#                         <th id="T_c890d_level0_row8" class="row_heading level0 row8" >MA-KA-RI-TE</th>
#                         <td id="T_c890d_row8_col0" class="data row8 col0" >11</td>
#             </tr>
#             <tr>
#                         <th id="T_c890d_level0_row9" class="row_heading level0 row9" >U-MI-NA-SI</th>
#                         <td id="T_c890d_row9_col0" class="data row9 col0" >11</td>
#             </tr>
#             <tr>
#                         <th id="T_c890d_level0_row10" class="row_heading level0 row10" >SA-RO</th>
#                         <td id="T_c890d_row10_col0" class="data row10 col0" >9</td>
#             </tr>
#             <tr>
#                         <th id="T_c890d_level0_row11" class="row_heading level0 row11" >*47-KU-NA</th>
#                         <td id="T_c890d_row11_col0" class="data row11 col0" >8</td>
#             </tr>
#             <tr>
#                         <th id="T_c890d_level0_row12" class="row_heading level0 row12" >KI-RA</th>
#                         <td id="T_c890d_row12_col0" class="data row12 col0" >8</td>
#             </tr>
#             <tr>
#                         <th id="T_c890d_level0_row13" class="row_heading level0 row13" >Tylissos Magazine</th>
#                         <td id="T_c890d_row13_col0" class="data row13 col0" >8</td>
#             </tr>
#             <tr>
#                         <th id="T_c890d_level0_row14" class="row_heading level0 row14" >*21F-*118</th>
#                         <td id="T_c890d_row14_col0" class="data row14 col0" >7</td>
#             </tr>
#             <tr>
#                         <th id="T_c890d_level0_row15" class="row_heading level0 row15" >A-SI-JA-KA</th>
#                         <td id="T_c890d_row15_col0" class="data row15 col0" >7</td>
#             </tr>
#             <tr>
#                         <th id="T_c890d_level0_row16" class="row_heading level0 row16" >I-TI-TI-KU-NI</th>
#                         <td id="T_c890d_row16_col0" class="data row16 col0" >7</td>
#             </tr>
#             <tr>
#                         <th id="T_c890d_level0_row17" class="row_heading level0 row17" >KA-*305</th>
#                         <td id="T_c890d_row17_col0" class="data row17 col0" >7</td>
#             </tr>
#             <tr>
#                         <th id="T_c890d_level0_row18" class="row_heading level0 row18" >Kharnia Magazine</th>
#                         <td id="T_c890d_row18_col0" class="data row18 col0" >7</td>
#             </tr>
#             <tr>
#                         <th id="T_c890d_level0_row19" class="row_heading level0 row19" >QE-RA₂-U</th>
#                         <td id="T_c890d_row19_col0" class="data row19 col0" >7</td>
#             </tr>
#             <tr>
#                         <th id="T_c890d_level0_row20" class="row_heading level0 row20" >QE-TI</th>
#                         <td id="T_c890d_row20_col0" class="data row20 col0" >7</td>
#             </tr>
#             <tr>
#                         <th id="T_c890d_level0_row21" class="row_heading level0 row21" >SA-RA₂</th>
#                         <td id="T_c890d_row21_col0" class="data row21 col0" >7</td>
#             </tr>
#             <tr>
#                         <th id="T_c890d_level0_row22" class="row_heading level0 row22" >U-TA-RO</th>
#                         <td id="T_c890d_row22_col0" class="data row22 col0" >7</td>
#             </tr>
#             <tr>
#                         <th id="T_c890d_level0_row23" class="row_heading level0 row23" >A-KA-RU</th>
#                         <td id="T_c890d_row23_col0" class="data row23 col0" >6</td>
#             </tr>
#             <tr>
#                         <th id="T_c890d_level0_row24" class="row_heading level0 row24" >Arkhalkhori Magazine</th>
#                         <td id="T_c890d_row24_col0" class="data row24 col0" >6</td>
#             </tr>
#             <tr>
#                         <th id="T_c890d_level0_row25" class="row_heading level0 row25" >DA-DU-MA-TA</th>
#                         <td id="T_c890d_row25_col0" class="data row25 col0" >6</td>
#             </tr>
#             <tr>
#                         <th id="T_c890d_level0_row26" class="row_heading level0 row26" >JE-DI</th>
#                         <td id="T_c890d_row26_col0" class="data row26 col0" >6</td>
#             </tr>
#             <tr>
#                         <th id="T_c890d_level0_row27" class="row_heading level0 row27" >KA-U-DE-TA</th>
#                         <td id="T_c890d_row27_col0" class="data row27 col0" >6</td>
#             </tr>
#             <tr>
#                         <th id="T_c890d_level0_row28" class="row_heading level0 row28" >KU-PA₃-NU</th>
#                         <td id="T_c890d_row28_col0" class="data row28 col0" >6</td>
#             </tr>
#             <tr>
#                         <th id="T_c890d_level0_row29" class="row_heading level0 row29" >Petras Magazine</th>
#                         <td id="T_c890d_row29_col0" class="data row29 col0" >6</td>
#             </tr>
#             <tr>
#                         <th id="T_c890d_level0_row30" class="row_heading level0 row30" >*301-U-RA</th>
#                         <td id="T_c890d_row30_col0" class="data row30 col0" >5</td>
#             </tr>
#             <tr>
#                         <th id="T_c890d_level0_row31" class="row_heading level0 row31" >DA-QE-RA</th>
#                         <td id="T_c890d_row31_col0" class="data row31 col0" >5</td>
#             </tr>
#             <tr>
#                         <th id="T_c890d_level0_row32" class="row_heading level0 row32" >SA-RU</th>
#                         <td id="T_c890d_row32_col0" class="data row32 col0" >5</td>
#             </tr>
#             <tr>
#                         <th id="T_c890d_level0_row33" class="row_heading level0 row33" >SA-TA</th>
#                         <td id="T_c890d_row33_col0" class="data row33 col0" >5</td>
#             </tr>
#             <tr>
#                         <th id="T_c890d_level0_row34" class="row_heading level0 row34" >SI-DA-TE</th>

# %%
import json
# Print out the top ten connected nodes
print(json.dumps([x for x,y in sorted(node_count.items(), key=lambda x:x[1], reverse=True)[:10]]))
# Out:
# ["Haghia Triada Magazine", "Zakros Magazine", "KA-PA", "KI-RO", "A-DU", "PA", "]-RA-RI", "KI-KI-RA-JA", "MA-KA-RI-TE", "U-MI-NA-SI"]

# %% [markdown]
# # Acyclic paths in the graph

# %%
# Find the longest acyclic paths up to a maximum of X.
def extendPath(p):
    legs = [p + [t] for f, t in edges if f == p[-1] and t not in p and "Magazine" not in t]
    return legs

def getMaxPathLength(n, maxLen=10):
    paths = [[n]]
    i = 0
    while i < maxLen:
        new_paths = []
        for p in paths:
            new_paths += extendPath(p)
        if not new_paths:
            break
        paths = new_paths
        i+=1
    return (i, len(paths), paths)


starting_nodes = list(set([f for f,t in edges]))
path_lengths = [(n,c) for n,c in [(n, getMaxPathLength(n,8)) for n in starting_nodes] if c[0] > 0]

# %%
df = pd.DataFrame([(a,b,c) for a,(b,c,d) in sorted(path_lengths, key=lambda p: p[1][1], reverse=True)],
                  columns=["Node", "Path Length", "No. of Paths"])
df.style.hide_index().set_caption("Most connected Nodes").set_table_styles(styles)
# Out:
# <style  type="text/css" >
#     #T_5c1f0_ caption {
#           text-align: center;
#           font-size: 120%;
#           color: black;
#     }</style><table id="T_5c1f0_" ><caption>Most connected Nodes</caption><thead>    <tr>        <th class="col_heading level0 col0" >Node</th>        <th class="col_heading level0 col1" >Path Length</th>        <th class="col_heading level0 col2" >No. of Paths</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_5c1f0_row0_col0" class="data row0 col0" >Haghia Triada Magazine</td>
#                         <td id="T_5c1f0_row0_col1" class="data row0 col1" >8</td>
#                         <td id="T_5c1f0_row0_col2" class="data row0 col2" >117309</td>
#             </tr>
#             <tr>
#                                 <td id="T_5c1f0_row1_col0" class="data row1 col0" >KU-RA-MU</td>
#                         <td id="T_5c1f0_row1_col1" class="data row1 col1" >8</td>
#                         <td id="T_5c1f0_row1_col2" class="data row1 col2" >43615</td>
#             </tr>
#             <tr>
#                                 <td id="T_5c1f0_row2_col0" class="data row2 col0" >MI-TU</td>
#                         <td id="T_5c1f0_row2_col1" class="data row2 col1" >8</td>
#                         <td id="T_5c1f0_row2_col2" class="data row2 col2" >43615</td>
#             </tr>
#             <tr>
#                                 <td id="T_5c1f0_row3_col0" class="data row3 col0" >TU-JU-MA</td>
#                         <td id="T_5c1f0_row3_col1" class="data row3 col1" >8</td>
#                         <td id="T_5c1f0_row3_col2" class="data row3 col2" >43615</td>
#             </tr>
#             <tr>
#                                 <td id="T_5c1f0_row4_col0" class="data row4 col0" >MI-RU-TA-RA-RE</td>
#                         <td id="T_5c1f0_row4_col1" class="data row4 col1" >8</td>
#                         <td id="T_5c1f0_row4_col2" class="data row4 col2" >43615</td>
#             </tr>
#             <tr>
#                                 <td id="T_5c1f0_row5_col0" class="data row5 col0" >MA-RU</td>
#                         <td id="T_5c1f0_row5_col1" class="data row5 col1" >8</td>
#                         <td id="T_5c1f0_row5_col2" class="data row5 col2" >43615</td>
#             </tr>
#             <tr>
#                                 <td id="T_5c1f0_row6_col0" class="data row6 col0" >U-DI-MI</td>
#                         <td id="T_5c1f0_row6_col1" class="data row6 col1" >8</td>
#                         <td id="T_5c1f0_row6_col2" class="data row6 col2" >43615</td>
#             </tr>
#             <tr>
#                                 <td id="T_5c1f0_row7_col0" class="data row7 col0" >TE-JA-RE</td>
#                         <td id="T_5c1f0_row7_col1" class="data row7 col1" >8</td>
#                         <td id="T_5c1f0_row7_col2" class="data row7 col2" >43615</td>
#             </tr>
#             <tr>
#                                 <td id="T_5c1f0_row8_col0" class="data row8 col0" >U-SU</td>
#                         <td id="T_5c1f0_row8_col1" class="data row8 col1" >8</td>
#                         <td id="T_5c1f0_row8_col2" class="data row8 col2" >43615</td>
#             </tr>
#             <tr>
#                                 <td id="T_5c1f0_row9_col0" class="data row9 col0" >NA-DA-RE</td>
#                         <td id="T_5c1f0_row9_col1" class="data row9 col1" >8</td>
#                         <td id="T_5c1f0_row9_col2" class="data row9 col2" >43615</td>
#             </tr>
#             <tr>
#                                 <td id="T_5c1f0_row10_col0" class="data row10 col0" >MA-KA-RI-TE</td>
#                         <td id="T_5c1f0_row10_col1" class="data row10 col1" >8</td>
#                         <td id="T_5c1f0_row10_col2" class="data row10 col2" >40562</td>
#             </tr>
#             <tr>
#                                 <td id="T_5c1f0_row11_col0" class="data row11 col0" >U-MI-NA-SI</td>
#                         <td id="T_5c1f0_row11_col1" class="data row11 col1" >8</td>
#                         <td id="T_5c1f0_row11_col2" class="data row11 col2" >36603</td>
#             </tr>
#             <tr>
#                                 <td id="T_5c1f0_row12_col0" class="data row12 col0" >KU-PA₃-NU</td>
#                         <td id="T_5c1f0_row12_col1" class="data row12 col1" >8</td>
#                         <td id="T_5c1f0_row12_col2" class="data row12 col2" >34512</td>
#             </tr>
#             <tr>
#                                 <td id="T_5c1f0_row13_col0" class="data row13 col0" >KU-NI-SU</td>
#                         <td id="T_5c1f0_row13_col1" class="data row13 col1" >8</td>
#                         <td id="T_5c1f0_row13_col2" class="data row13 col2" >30700</td>
#             </tr>
#             <tr>
#                                 <td id="T_5c1f0_row14_col0" class="data row14 col0" >DI-DE-RU</td>
#                         <td id="T_5c1f0_row14_col1" class="data row14 col1" >8</td>
#                         <td id="T_5c1f0_row14_col2" class="data row14 col2" >30033</td>
#             </tr>
#             <tr>
#                                 <td id="T_5c1f0_row15_col0" class="data row15 col0" >SA-RU</td>
#                         <td id="T_5c1f0_row15_col1" class="data row15 col1" >8</td>
#                         <td id="T_5c1f0_row15_col2" class="data row15 col2" >29182</td>
#             </tr>
#             <tr>
#                                 <td id="T_5c1f0_row16_col0" class="data row16 col0" >QE-RA₂-U</td>
#                         <td id="T_5c1f0_row16_col1" class="data row16 col1" >8</td>
#                         <td id="T_5c1f0_row16_col2" class="data row16 col2" >28331</td>
#             </tr>
#             <tr>
#                                 <td id="T_5c1f0_row17_col0" class="data row17 col0" >KI-RO</td>
#                         <td id="T_5c1f0_row17_col1" class="data row17 col1" >8</td>
#                         <td id="T_5c1f0_row17_col2" class="data row17 col2" >26657</td>
#             </tr>
#             <tr>
#                                 <td id="T_5c1f0_row18_col0" class="data row18 col0" >DA-DU-MA-TA</td>
#                         <td id="T_5c1f0_row18_col1" class="data row18 col1" >8</td>
#                         <td id="T_5c1f0_row18_col2" class="data row18 col2" >26527</td>
#             </tr>
#             <tr>
#                                 <td id="T_5c1f0_row19_col0" class="data row19 col0" >A-DU</td>
#                         <td id="T_5c1f0_row19_col1" class="data row19 col1" >8</td>
#                         <td id="T_5c1f0_row19_col2" class="data row19 col2" >26170</td>
#             </tr>
#             <tr>
#                                 <td id="T_5c1f0_row20_col0" class="data row20 col0" >DA-RI-DA</td>
#                         <td id="T_5c1f0_row20_col1" class="data row20 col1" >8</td>
#                         <td id="T_5c1f0_row20_col2" class="data row20 col2" >25743</td>
#             </tr>
#             <tr>
#                                 <td id="T_5c1f0_row21_col0" class="data row21 col0" >DA-ME</td>
#                         <td id="T_5c1f0_row21_col1" class="data row21 col1" >8</td>
#                         <td id="T_5c1f0_row21_col2" class="data row21 col2" >25503</td>
#             </tr>
#             <tr>
#                                 <td id="T_5c1f0_row22_col0" class="data row22 col0" >DA-SI-*118</td>
#                         <td id="T_5c1f0_row22_col1" class="data row22 col1" >8</td>
#                         <td id="T_5c1f0_row22_col2" class="data row22 col2" >25485</td>
#             </tr>
#             <tr>
#                                 <td id="T_5c1f0_row23_col0" class="data row23 col0" >MI-NU-TE</td>
#                         <td id="T_5c1f0_row23_col1" class="data row23 col1" >8</td>
#                         <td id="T_5c1f0_row23_col2" class="data row23 col2" >24659</td>
#             </tr>
#             <tr>
#                                 <td id="T_5c1f0_row24_col0" class="data row24 col0" >A-SI-JA-KA</td>
#                         <td id="T_5c1f0_row24_col1" class="data row24 col1" >8</td>
#                         <td id="T_5c1f0_row24_col2" class="data row24 col2" >223

# %%
# Get a list of nodes in the longest paths that all contain a given node
flatten = lambda l: [item for sublist in l for item in sublist]

l = list(set(flatten([p for a,(b,c,d) in path_lengths for p in d if "MA-RU" in p])))
l
# Out:
# ['U-TI',
#  'JA-*21F',
#  'SA-PO',
#  '*21F-TU-NE',
#  'DA-ME',
#  'Haghia Triada Magazine',
#  'KI-RO',
#  'KI-RE-TA₂',
#  'TE-KI',
#  'SA-RA₂',
#  'QA-NU-MA',
#  'DE-DI',
#  'KA-U-DE-TA',
#  'DI-DE-RU',
#  'TU-MA',
#  'PA',
#  'U-SU',
#  'QA-RA₂-WA',
#  'I-RU-JA',
#  'I-TA-JA',
#  'Kharnia Magazine',
#  'DI-DI-ZA-KE',
#  'I-DU-NE-SI',
#  'SA-RO',
#  'QA-QA-RU',
#  'A-DU',
#  'SI-KI-NE',
#  'MA-DI',
#  'DU-DA-MA',
#  'JA-MI-DA-RE',
#  'RE-TE',
#  'KA-SA-RU',
#  ']-RA-RI',
#  'QE-RA₂-U',
#  'MA-*321',
#  'DA-RU-*329',
#  'A-SI',
#  'TA',
#  'MA-*79',
#  '*188',
#  'SA-RU',
#  'KI-RE-TA-NA',
#  'KU-NI-SU',
#  'MA-RU',
#  'Tylissos Magazine',
#  'KU-PA₃-NU',
#  'MA-KA-RI-TE',
#  'SI-RU-MA-RI-TA₂',
#  'KI-KI-RA-JA',
#  'U-MI-NA-SI',
#  'QA-*310-I',
#  '*312-TA',
#  'KA-PA',
#  'DU',
#  'SU-DU',
#  'U-DI-MI',
#  'PI-*34-TE',
#  'QE-TI',
#  'WI-DI-NA',
#  'WI',
#  'RE-DI-SE',
#  'MI-NU-TE',
#  'DA-RE',
#  'PA-[I-TO',
#  'TA-RI-NA',
#  'I-KU-RI-NA',
#  'RA-TI-SE',
#  'WA-DU-NI-MI',
#  'SA-MA',
#  'DI',
#  'U-TA-RO',
#  'DA-TA-RA',
#  'TA-NA-TI',
#  'ME-ZA',
#  'KU-RA-MU',
#  'DA-DU-MA-TA',
#  'PU-RA₂',
#  'DI-NA-U',
#  'DI-DE',
#  'U-*325-ZA',
#  'RE-ZA',
#  '*306-TU',
#  'DA-RI-DA',
#  'PA₃-NI',
#  'TE-KE',
#  'VIR+[?]',
#  'Zakros Magazine',
#  'PA-TA-NE',
#  'TU-JU-MA',
#  'KA',
#  'KE-KI-RU',
#  'KA-*305',
#  'MI-RU-TA-RA-RE',
#  'KU-*79-NI',
#  '*324-DI-RA',
#  'TA-I-AROM',
#  'DA-KI',
#  'KA-PA-QE',
#  'QE-PU',
#  'NA-DA-RE',
#  'SI-DA-RE',
#  'PI-TA-JA',
#  'A-RU',
#  'SI+SE',
#  'KI-RI-TA₂',
#  'TE-TU',
#  'JE-DI',
#  'PA₃-NI-NA',
#  'DI-RI-NA',
#  'DA-U-*49',
#  '*306-KI-TA₂',
#  'PA-I-TO',
#  '*79-SU',
#  'TE-JA-RE',
#  'I-KA',
#  'KA-KU-PA',
#  'MA-RI-RE-I',
#  'A-RU-DA-RA',
#  'QE-PI-TA',
#  'QE-KA',
#  '*305-RU',
#  'DA-QE-RA',
#  '*301',
#  'MI-TU',
#  'DA-JU-TE',
#  'O-RA₂-DI-NE',
#  'DU-JA',
#  'A-SI-JA-KA',
#  'A-RA-NA-RE',
#  'KU-PA-JA',
#  'DA-SI-*118',
#  'A-RA-JU-U-DE-ZA',
#  'TE',
#  'A-KA-RU',
#  ']-DI',
#  'U-DE-ZA',
#  'PA-DE']

# %% [markdown]
# # Cyclic Paths in the Graph

# %%
# Find the longest cyclic paths up to a maximum of X.
def getPaths(p):
    legs = [p + [t] for f, t in edges 
            if f == p[-1] and (t == p[0] or t not in p) and "Magazine" not in t]
    return legs

def getCycles(n, maxLen=10):
    paths = [[n]]
    cycles = []
    i = 0
    while i < maxLen:
        new_paths = []
        for p in paths:
            new_paths += getPaths(p)
        if not new_paths:
            break
        paths = [p for p in new_paths if p[0] != p[-1]]
        cycles += [p for p in new_paths if p[0] == p[-1]]
        i+=1
    if not len(cycles):
        return (0,0,[])
    return (max([len(c) for c in cycles]), len(cycles), sorted(cycles, key=lambda l: len(l), reverse=True))

# Store results in a dict while we try different path lengths.
path_lengths = {}

# %%
# %%time

import multiprocessing

# split a list into evenly sized chunks
def chunks(l, n):
    return [l[i:i+n] for i in range(0, len(l), n)]

MAX_PATH_LENGTH = 11
def worker(nodes):
    path_lengths = [(n,c) for n,c in [(n, getCycles(n, MAX_PATH_LENGTH)) for n in nodes] if c[0] > 0]
    return path_lengths

starting_nodes = list(set([f for f,t in edges]))
total = len(starting_nodes)
chunk_size = total / 10
batches = chunks(starting_nodes, int(chunk_size))

pool = multiprocessing.Pool(processes = 3)
path_lengths[MAX_PATH_LENGTH] = flatten(pool.map(worker, batches))
# Out:
# CPU times: user 913 ms, sys: 129 ms, total: 1.04 s
# Wall time: 13min 14s
# Process ForkPoolWorker-20:
# Process ForkPoolWorker-19:
# Process ForkPoolWorker-21:
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.8/multiprocessing/queues.py", line 355, in get
#     with self._rlock:
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib/python3.8/multiprocessing/queues.py", line 355, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/usr/lib/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib/python3.8/multiprocessing/queues.py", line 356, in get
#     res = self._reader.recv_bytes()
#   File "/usr/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/usr/lib/python3.8/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/usr/lib/python3.8/multiprocessing/connection.py", line 414, in _recv_bytes
#     buf = self._recv(4)
#   File "/usr/lib/python3.8/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt

# %%
df = pd.DataFrame([(a,b,c,d[0]) for a,(b,c,d) in sorted(path_lengths[MAX_PATH_LENGTH], key=lambda p: p[1][1], reverse=True)],
                  columns=["Node", "Max Path Length", "No. of Cyclic Paths", "Example"])
df.style.hide_index().set_caption("Most cyclic paths").set_table_styles(styles)
# Out:
# <style  type="text/css" >
#     #T_e187a_ caption {
#           text-align: center;
#           font-size: 120%;
#           color: black;
#     }</style><table id="T_e187a_" ><caption>Most cyclic paths</caption><thead>    <tr>        <th class="col_heading level0 col0" >Node</th>        <th class="col_heading level0 col1" >Max Path Length</th>        <th class="col_heading level0 col2" >No. of Cyclic Paths</th>        <th class="col_heading level0 col3" >Example</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_e187a_row0_col0" class="data row0 col0" >KI-RO</td>
#                         <td id="T_e187a_row0_col1" class="data row0 col1" >12</td>
#                         <td id="T_e187a_row0_col2" class="data row0 col2" >21159</td>
#                         <td id="T_e187a_row0_col3" class="data row0 col3" >['KI-RO', 'KU-PA₃-NU', 'MA-KA-RI-TE', '*21F-TU-NE', 'QE-TI', 'DA-RE', 'A-DU', 'SA-RA₂', 'A-SI-JA-KA', 'U-MI-NA-SI', 'KU-RA-MU', 'KI-RO']</td>
#             </tr>
#             <tr>
#                                 <td id="T_e187a_row1_col0" class="data row1 col0" >A-DU</td>
#                         <td id="T_e187a_row1_col1" class="data row1 col1" >12</td>
#                         <td id="T_e187a_row1_col2" class="data row1 col2" >20114</td>
#                         <td id="T_e187a_row1_col3" class="data row1 col3" >['A-DU', 'DA-ME', 'DA-DU-MA-TA', 'DI-DE-RU', 'A-KA-RU', 'SA-RU', 'KI-RO', 'KU-PA₃-NU', 'U-MI-NA-SI', 'A-SI-JA-KA', 'SA-RA₂', 'A-DU']</td>
#             </tr>
#             <tr>
#                                 <td id="T_e187a_row2_col0" class="data row2 col0" >U-MI-NA-SI</td>
#                         <td id="T_e187a_row2_col1" class="data row2 col1" >12</td>
#                         <td id="T_e187a_row2_col2" class="data row2 col2" >17565</td>
#                         <td id="T_e187a_row2_col3" class="data row2 col3" >['U-MI-NA-SI', 'A-SI-JA-KA', 'SA-RA₂', 'A-DU', 'DA-ME', 'DA-DU-MA-TA', 'DI-DE-RU', 'A-KA-RU', 'SA-RU', 'KI-RO', 'KU-PA₃-NU', 'U-MI-NA-SI']</td>
#             </tr>
#             <tr>
#                                 <td id="T_e187a_row3_col0" class="data row3 col0" >MA-KA-RI-TE</td>
#                         <td id="T_e187a_row3_col1" class="data row3 col1" >12</td>
#                         <td id="T_e187a_row3_col2" class="data row3 col2" >17343</td>
#                         <td id="T_e187a_row3_col3" class="data row3 col3" >['MA-KA-RI-TE', '*21F-TU-NE', 'QE-TI', 'DA-RE', 'A-DU', 'DA-ME', 'DA-DU-MA-TA', 'QE-RA₂-U', 'KU-PA₃-NU', 'KI-RO', 'KU-RA-MU', 'MA-KA-RI-TE']</td>
#             </tr>
#             <tr>
#                                 <td id="T_e187a_row4_col0" class="data row4 col0" >KU-PA₃-NU</td>
#                         <td id="T_e187a_row4_col1" class="data row4 col1" >12</td>
#                         <td id="T_e187a_row4_col2" class="data row4 col2" >16127</td>
#                         <td id="T_e187a_row4_col3" class="data row4 col3" >['KU-PA₃-NU', 'KI-RO', 'KU-RA-MU', 'MA-KA-RI-TE', '*21F-TU-NE', 'QE-TI', 'DA-RE', 'A-DU', 'DA-ME', 'DA-DU-MA-TA', 'QE-RA₂-U', 'KU-PA₃-NU']</td>
#             </tr>
#             <tr>
#                                 <td id="T_e187a_row5_col0" class="data row5 col0" >QE-RA₂-U</td>
#                         <td id="T_e187a_row5_col1" class="data row5 col1" >12</td>
#                         <td id="T_e187a_row5_col2" class="data row5 col2" >14169</td>
#                         <td id="T_e187a_row5_col3" class="data row5 col3" >['QE-RA₂-U', 'A-DU', 'DA-ME', 'DA-DU-MA-TA', 'DI-DE-RU', 'A-KA-RU', 'SA-RU', 'KI-RO', 'KU-RA-MU', 'MA-KA-RI-TE', 'KU-PA₃-NU', 'QE-RA₂-U']</td>
#             </tr>
#             <tr>
#                                 <td id="T_e187a_row6_col0" class="data row6 col0" >SA-RU</td>
#                         <td id="T_e187a_row6_col1" class="data row6 col1" >12</td>
#                         <td id="T_e187a_row6_col2" class="data row6 col2" >11482</td>
#                         <td id="T_e187a_row6_col3" class="data row6 col3" >['SA-RU', 'A-DU', 'DA-ME', 'DA-DU-MA-TA', 'QE-RA₂-U', 'KU-PA₃-NU', 'MA-KA-RI-TE', 'KU-RA-MU', 'U-MI-NA-SI', 'MA-RU', 'KI-RO', 'SA-RU']</td>
#             </tr>
#             <tr>
#                                 <td id="T_e187a_row7_col0" class="data row7 col0" >DA-DU-MA-TA</td>
#                         <td id="T_e187a_row7_col1" class="data row7 col1" >12</td>
#                         <td id="T_e187a_row7_col2" class="data row7 col2" >10532</td>
#                         <td id="T_e187a_row7_col3" class="data row7 col3" >['DA-DU-MA-TA', 'DA-ME', 'A-DU', 'DA-RE', 'JE-DI', 'DI', 'KI-KI-RA-JA', 'QA-*310-I', ']-RA-RI', 'KU-PA₃-NU', 'QE-RA₂-U', 'DA-DU-MA-TA']</td>
#             </tr>
#             <tr>
#                                 <td id="T_e187a_row8_col0" class="data row8 col0" >]-RA-RI</td>
#                         <td id="T_e187a_row8_col1" class="data row8 col1" >12</td>
#                         <td id="T_e187a_row8_col2" class="data row8 col2" >9217</td>
#                         <td id="T_e187a_row8_col3" class="data row8 col3" >[']-RA-RI', '*306-TU', 'SA-RO', 'TA', 'SI+SE', 'U-TA-RO', 'PU-RA₂', 'A-SI-JA-KA', 'SA-RA₂', 'A-DU', 'DA-RI-DA', ']-RA-RI']</td>
#             </tr>
#             <tr>
#                                 <td id="T_e187a_row9_col0" class="data row9 col0" >SA-RA₂</td>
#                         <td id="T_e187a_row9_col1" class="data row9 col1" >12</td>
#                         <td id="T_e187a_row9_col2" class="data row9 col2" >7126</td>
#                         <td id="T_e187a_row9_col3" class="data row9 col3" >['SA-RA₂', 'A-DU', 'DA-ME', 'DA-DU-MA-TA', 'DI-DE-RU', 'A-KA-RU', 'SA-RU', 'KI-RO', 'KU-PA₃-NU', 'U-MI-NA-SI', 'A-SI-JA-KA', 'SA-RA₂']</td>
#             </tr>
#             <tr>
#                                 <td id="T_e187a_row10_col0" class="data row10 col0" >A-SI-JA-KA</td>
#                         <td id="T_e187a_row10_col1" class="data row10 col1" >12</td>
#                         <td id="T_e187a_row10_col2" class="data row10 col2" >6863</td>
#                         <td id="T_e187a_row10_col3" class="data row10 col3" >['A-SI-JA-KA', 'PU-RA₂', 'U-TA-RO', 'SI+SE', 'TA', 'SA-RO', '*306-TU', ']-RA-RI', 'DA-RI-DA', 'A-DU', 'SA-RA₂', 'A-SI-JA-KA']</td>
#             </tr>
#             <tr>
#                                 <td id="T_e187a_row11_col0" class="data row11 col0" >KU-NI-SU</td>
#                         <td id="T_e187a_row11_col1" class="data row11 col1" >12</td>
#                         <td id="T_e187a_row11_col2" class="data row11 col2" >4420</td>
#                         <td id="T_e187a_row11_col3" class="data row11 col3" >['KU-NI-SU', 'A-DU', 'DA-ME', 'DA-DU-MA-TA', 'QE-RA₂-U', 'KU-PA₃-NU', 'MA-KA-RI-TE', 'KU-RA-MU', 'KI-RO', 'SA-RU', 'A-KA-RU', 'KU-NI-SU']</td>
#             </tr>
#             <tr>
#                                 <td id="T_e187a_row12_col0" class="data row12 col0" >DA-RI-DA</td>
#                         <td id="T_e187a_row12_col1" class="data row12 col1" >12</td>
#                         <td id="T_e187a_row12_col2" class="data row12 col2" >4365</td>
#                         <td id="T_e187a_row12_col3" class="data row12 col3" >['DA-RI-DA', 'A-DU', 'DA-ME', 'DA-DU-MA-TA', 'DI-DE-RU', 'A-KA-RU', 'SA-RU', 'KI-RO', 'QE-RA₂-U', 'KU-PA₃-NU', ']-RA-RI', 'DA-RI-DA']</td>
#             </tr>
#             <tr>
#                                 <td id="T_e187a_row13_col0" class="data row13 col0" >DI-DE-RU</td>
#                         <td id="T_e187a_row13_col1" class="data row13 col1" >12</td>
#                         <td id="T_e187a_row13_col2" class="data row13 col2" >3821</td>
#                         <td id="T_e187a_row13_col3" class="data row13 col3" >['DI-DE-RU', 'A-DU', 'DA-ME', 'DA-DU-MA-TA', 'QE-RA₂-U', 'KU-PA₃-NU', 'MA-KA-RI-TE', 'KU-RA-MU', 'KI-RO', 'SA-RU', 'A-KA-RU', 'DI-DE-RU']</td>
#             </tr>
#             <tr>
#                                 <td id="T_e187a_row14_col0" class="data row14 col0" >DA-SI-*118</td>
#                         <td id="T_e187a_row14_col1" class="data row14 col1" >12</td>
#                         <td id="T_e187a_row14_col2" clas

# %%
def isSameCycle(c1,c2):
    c1 = c1[:-1]
    c2 = c2[:-1]
    if len(c1) != len(c2):
        return False
    if sorted(c1) != sorted(c2):
        return False
    s = c2.index(c1[0])
    c2a = c2[s:] + c2[:s]
    if c1 == c2a:
        return True
    print(c1,c2a)
    return False

# %%
c1 = ['DA-DU-MA-TA', 'DA-ME', 'A-DU', 'DA-RE', 'JE-DI', 'DI', 'KI-KI-RA-JA', 'QA-*310-I', ']-RA-RI', 'KU-PA₃-NU', 'QE-RA₂-U', 'DA-DU-MA-TA']
c2 = ['DA-RE', 'JE-DI', 'DI', 'KI-KI-RA-JA', 'QA-*310-I', ']-RA-RI', 'KU-PA₃-NU', 'QE-RA₂-U', 'DA-DU-MA-TA', 'DA-ME', 'A-DU', 'DA-RE']

isSameCycle(c1,c2)
# Out:
# True

# %%
# %%time

import networkx as nx
import matplotlib.pyplot as plt

# Create Directed Graph
G=nx.Graph()

# Create a list of all edges
edges = [(senders[k], recipients[k]) for k in recipients]
edges = [(recipients[k], senders[k]) for k in recipients]
edges = sorted(set(edges))
#edges = [(a,b) for (a,b) in edges if "Magazine" not in a and "Magazine" not in b]

nodes = sorted(set([a for (a,b) in edges] + [b for (a,b) in edges]))

# Add a list of nodes:
G.add_nodes_from(nodes)

# Add a list of edges:
G.add_edges_from(edges)
# Out:
# CPU times: user 3.3 ms, sys: 0 ns, total: 3.3 ms
# Wall time: 3.21 ms

# %%
#Return a list of cycles described as a list o nodes
cycles = list(nx.simple_cycles(G))
cycles

# %%
from networkx.algorithms.community import k_clique_communities
list(k_clique_communities(G, 3))
# Out:
# [frozenset({'*21F-*118', '*28B-NU-MA-RE', 'SI-PI-KI', 'Zakros Magazine'}),
#  frozenset({'A-DU',
#             'A-KA-RU',
#             'DA-SI-*118',
#             'Haghia Triada Magazine',
#             'I-KA',
#             'KA-PA',
#             'KI-RI-TA₂',
#             'KI-RO',
#             'KU-PA₃-NU',
#             'MI-NU-TE',
#             'QE-RA₂-U',
#             'SA-RA₂',
#             'SA-RU'}),
#  frozenset({'*306-TU',
#             'DI-NA-U',
#             'Haghia Triada Magazine',
#             'SA-RO',
#             'TA-I-AROM'}),
#  frozenset({'A-RI-NI-TA', 'Haghia Triada Magazine', 'KI-RA'}),
#  frozenset({'DI', 'Haghia Triada Magazine', 'JE-DI'}),
#  frozenset({'KI-KI-RA-JA', 'ME-ZA', 'PA'})]

# %%
import networkx.algorithms.community as nx_comm
nx_comm.louvain_communities(G, seed=123)
# Out:
# [{'*301-NA', 'KU-PA-ZU', 'WI-NA-DU'},
#  {'*301-U-RA',
#   'A-SE-JA',
#   'KA-PO-RU',
#   'NA-*21F-NE-MI-NA',
#   'PA-RA-NE',
#   'SE-KU-TU'},
#  {'*312-TE-TE', 'MI-KI-SE-NA', 'TA-TI', 'U-NU-*21F'},
#  {'A-*325-ZA',
#   'A-RI-PA',
#   'Petras Magazine',
#   'QA-QA-DA',
#   'RU-PI-*305-MI',
#   'TO-*49-RE',
#   'TO-ME'},
#  {'*21F-TU-NE',
#   '*301',
#   '*305-RU',
#   '*306-KI-TA₂',
#   '*312-TA',
#   'A-RA-JU-U-DE-ZA',
#   'DA-RE',
#   'DA-RI-DA',
#   'DA-RU-*329',
#   'DI',
#   'DU-JA',
#   'I-RU-JA',
#   'JE-DI',
#   'KA',
#   'KA-SA-RU',
#   'KI-KI-RA-JA',
#   'KI-RE-TA₂',
#   'MA-DI',
#   'ME-ZA',
#   'PA',
#   'QA-*310-I',
#   'QA-QA-RU',
#   'QE-KA',
#   'QE-TI',
#   'RE-DI-SE',
#   'TA-NA-TI',
#   'TA-RI-NA',
#   'TE-TU',
#   'U-TI',
#   'WA-DU-NI-MI'},
#  {'A-DA-KI-SI-KA', 'A-RA-U-DA', 'WI-SA-SA-NE'},
#  {'A-DA-RO',
#   'A-DU-NI-TA-NA',
#   'Arkhalkhori Magazine',
#   'JA-PI',
#   'KA-NE',
#   'KI-NU',
#   'PI-*314'},
#  {'A-DA',
#   'A-DU',
#   'A-KA-RU',
#   'A-KU-TU-*361',
#   'DA-DU-MA-TA',
#   'DA-ME',
#   'DA-QE-RA',
#   'DA-U-*49',
#   'DI-DE',
#   'DI-DE-RU',
#   'KI-RE-TA-NA',
#   'KI-RI-SI',
#   'KO-A-DU-WA',
#   'KU-NI-SU',
#   'MI-NU-TE',
#   'PA-I-TO',
#   'PA₃-NI',
#   'PI-KU-ZU',
#   'QA-RA₂-WA',
#   'SA-MA',
#   'SA-RU',
#   'TE-KE',
#   'Tylissos Magazine',
#   'U-*325-ZA',
#   'ZA-*321'},
#  {'DU-AROM-A', 'U-*34-SI'},
#  {'E-NA-SI', 'Khania Magazine', 'PA-NA-TU', 'U-TA-I-SE'},
#  {'*318-*306',
#   '*322-RI',
#   '*327',
#   '*327-JU',
#   '*560',
#   '*79',
#   '*79-*22F-DI',
#   '*79-DU',
#   '*79-JU-PU₂',
#   "*86+'*188'",
#   'A-PU₂-NA-DU',
#   'A-RE-DA-I',
#   'A-RU-RA',
#   'A-SA-RA₂',
#   'A-SE',
#   'A-SU-JA',
#   'DA-KU-NA',
#   'DA-TA-RE',
#   'DA-TU',
#   'DI-JA-I',
#   'DI-NA-RO',
#   'DU-ME-DI',
#   'DU-RU-WI',
#   'DU-SU-NI',
#   'DU-ZU',
#   'Haghia Triada Magazine',
#   'I-KI-RA',
#   'I-QA-*118',
#   'JA-*345',
#   'JU',
#   'KA-DU-MA-NE',
#   'KA-JU',
#   'KA-NA',
#   'KA-NU-TI',
#   'KA-RO-NA',
#   'KA-RU',
#   'KA-TI',
#   'KI',
#   'KI-DA-TA',
#   'KI-KI-NA',
#   'KI-TA',
#   'KI-TA-I',
#   'KO-JA',
#   'KU-PA₃',
#   'KU-PA₃-NA-TU',
#   'KU-PA₃-PA₃',
#   'KU-PA₃-RI-JA',
#   'KU-RE-JU',
#   'KU-RO',
#   'MA',
#   'MI-DA',
#   'NA-TI',
#   'NI-RA',
#   'NU-DU-*331',
#   'PA-SA-RI-JA',
#   'PA-SE',
#   'PA₃',
#   'PA₃-*188',
#   'PA₃-KA-RA-TI',
#   'PI-TA-KA-SE',
#   'PU-VIN',
#   'QA-RE-TO',
#   'QA-TI-DA-TE',
#   'QE-TI-RA-DU',
#   'QE-TU-NE',
#   'RA-*164-TI',
#   'RA-\U000fd1eb-TI',
#   'RA₂',
#   'RA₂-TI',
#   'RE-TA₂',
#   'RI-*305',
#   'RI-KA-TA',
#   'RI-MI-SI',
#   'RU-I-KO',
#   'RU-MA-TA',
#   'RU-NI',
#   'SA-*323-MI',
#   'SA-MA-RO',
#   'SA-MA-TI',
#   'SI+SE-NI',
#   'SI-DU-*34-KU-MI',
#   'SI-KI-RA',
#   'SU-PU₂',
#   'SU-PU₂-*188',
#   'SU-RE',
#   'TA₂',
#   'TE-*301',
#   'TE-RI',
#   'TI',
#   'TU-*21F-RI-NA',
#   'TU-QE-NU',
#   'U-RE-WI',
#   'U-TA₂',
#   'VIR+[?]-I',
#   'lacuna'},
#  {'DA-KU-SE-NE', 'I-DU', 'PA-DA-SU-TI', 'TA-PA'},
#  {'I-JA-PA-ME', 'QA-TI-KI'},
#  {'DA-JU-TE',
#   'DA-KI',
#   'DA-TA-RA',
#   'DI-RI-NA',
#   'DU-DA-MA',
#   'I-KA',
#   'I-KU-RI-NA',
#   'KA-PA',
#   'KA-PA-QE',
#   'KI-RI-TA₂',
#   'MA-*321',
#   'MA-*79',
#   'MA-RI-RE-I',
#   'O-RA₂-DI-NE',
#   'PA₃-NI-NA',
#   'PI-TA-JA',
#   'QE-PI-TA',
#   'RA-TI-SE',
#   'SA-RA₂',
#   'SI-RU-MA-RI-TA₂',
#   'VIR+[?]',
#   'WI'},
#  {'I-KU-TA', 'TI-TI-KU'},
#  {'*323-*317',
#   '*323-*344',
#   'A-AROM-TE',
#   'A-PA-RA-NE',
#   'I-TI-TI-KU-NI',
#   'PI-TA-RA',
#   'QA-*118-RA-RE',
#   'RU-SA',
#   'SI-MI-TA'},
#  {'JA-DI-WI', 'Knossos Magazine'},
#  {'*21F-*118',
#   '*28B-NU-MA-RE',
#   '*363-KE-MA-SE',
#   '*47-KU-NA',
#   'I-TI-NI-SA',
#   'JA-SA-MU',
#   'KI-NI-MA',
#   'MA-KA-I-TA',
#   'MI-ZA-SE',
#   'O-TA-NI-ZA-SE',
#   'QE-SI-*79-E',
#   'SA-MI-DA-E',
#   'SI-PI-KI'},
#  {'A-RI-NI-TA',
#   'A-TA-RE',
#   'DA-I-PI-TA',
#   'KA-I-RO',
#   'KI-RA',
#   'KU-TU-KO-RE',
#   'MA-KA-I-SE',
#   'TA-I-NU-MA-PA'},
#  {'*306+MI', '*306-TU-JA', 'A-I', 'KU-RU-MA', 'KU-TA'},
#  {'MA-RI', 'MI-TA', 'PA-RA', 'TU-RU-NU-SE-ME', 'WA-TU-MA-RE'},
#  {'MA-SI-DU', 'PA-*342-I'},
#  {'KU-MA-JU', 'PA-RO-SU', 'QE-KU-RE', 'SA-RE-JU'},
#  {'*188',
#   '*79-SU',
#   'A-RA-NA-RE',
#   'DE-DI',
#   'DI-DI-ZA-KE',
#   'KE-KI-RU',
#   'KI-RO',
#   'KU-PA₃-NU',
#   'KU-RA-MU',
#   'MA-KA-RI-TE',
#   'MA-RU',
#   'MI-RU-TA-RA-RE',
#   'MI-TU',
#   'NA-DA-RE',
#   'QE-RA₂-U',
#   'TE-JA-RE',
#   'TU-JU-MA',
#   'TU-MA',
#   'U-DI-MI',
#   'U-MI-NA-SI',
#   'U-SU'},
#  {'*21F-TU', 'DE-ME-TE', 'RA'},
#  {'*47-NU-RA-JA', 'RI-TA-MA-NU-WI'},
#  {'DE-NU', 'RU-RA₂', 'RU-ZU-NA', 'SA-QE-RI'},
#  {'*306-TU',
#   '*324-DI-RA',
#   'A-RU',
#   'A-SI',
#   'DA-SI-*118',
#   'DI-NA-U',
#   'DU',
#   'I-DU-NE-SI',
#   'JA-MI-DA-RE',
#   'KA-*305',
#   'KA-KU-PA',
#   'KA-U-DE-TA',
#   'KU-*79-NI',
#   'PA-DE',
#   'PA-TA-NE',
#   'PA-[I-TO',
#   'QE-PU',
#   'RE-ZA',
#   'SA-PO',
#   'SA-RO',
#   'SI-DA-RE',
#   'TA-I-AROM',
#   'TE-KI',
#   'U-DE-ZA',
#   ']-DI',
#   ']-RA-RI'},
#  {'DA-MI-NU', 'DA-NE-KU-TI', 'KI-DA-RO', 'KO-SA-I-TI', 'KU-KU-DA-RA', 'SA-TA'},
#  {'*79-*301-SE-DE-*21F-*118',
#   'A-SI-DA-TO-I',
#   'A-SU-PU-WA',
#   'KU-RA',
#   'RU-MI',
#   'SI-DA-TE'},
#  {'DU-PA₃-NA', 'NU-WI', 'TI-NU-JA'},
#  {'A-SE-SI-NA', 'E-KA', 'KU-PA-RI', 'U-KA-RE'},
#  {'A-RU-DA-RA',
#   'A-SI-JA-KA',
#   'A-SI-SU-PO-A',
#   'A-TA-*350',
#   'A-TO-*349-TO-I',
#   'I-SI',
#   'I-TA-JA',
#   'JA-*21F',
#   'KU-PA-JA',
#   'Kharnia Magazine',
#   'PI-*34-TE',
#   'PU-DE',
#   'PU-RA₂',
#   'QA-NU-MA',
#   'RE-TE',
#   'SI+SE',
#   'SI-KI-NE',
#   'SU-DU',
#   'TA',
#   'TE',
#   'U-TA-RO',
#   'WI-DI-NA'},
#  {'*305-WA-NA',
#   '*312-TA₂',
#   '*34-JU-TE-MI',
#   'A-DE',
#   'A-DU-KU-MI-NA',
#   'A-KU-MI-NA',
#   'A-MI-DA-U',
#   'A-MI-TA',
#   'A-NA',
#   'A-RA-TU',
#   'A-RE-TU-MI',
#   'A-TA-NA',
#   'A-TA-NA-TE',
#   'A-TI-RU',
#   'DA-NA-SI',
#   'DI-DI-KO-RA-ME-TA₂',
#   'DU-RE-ZA-SE',
#   'E-*82',
#   'E-KU',
#   'E-TO-RI',
#   'I-KU-JU-TI-*28B',
#   'I-MA',
#   'I-SE',
#   'JA-PA',
#   'JA-TO-JA',
#   'JA-WI',
#   'KA-DI',
#   'KA-KU-NE-TE',
#   'KI-RE-ZA',
#   'KU-PA',
#   'KU-PI',
#   'MA-JU',
#   'MA-KI-DE-TE',
#   'MA-ZA',
#   'ME-KI-DI',
#   'PA-JA-RE',
#   'PA-NU-QE',
#   'PA-ZA',
#   'PI-*310-A',
#   'PU-NI-KA-*363',
#   'PU₂-RA₂',
#   'QA-TI-JU',
#   'RA-MA-SI',
#   'RA₂-RO-RE',
#   'RO-SI-RA',
#   'RU-MA-TA-SE',
#   'SA-*301-RI',
#   'SE',
#   'SI-DI-JA',
#   'SI-TE-TU',
#   'SI-TU',
#   'TA-NA-TE',
#   'TE-AROM',
#   'TU-ME-SE',
#   'TU-MI-TI-ZA-SE',
#   'U-*49',
#   'U-JU',
#   'WA-*362',
#   'WI-RA-RE-MI-TE',
#   'Zakros Magazine'},
#  {'KI-DE-MA-*323-NA', 'PU-KO', ']-TI-SA'}]
